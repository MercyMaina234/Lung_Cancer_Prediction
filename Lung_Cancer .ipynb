# %% [markdown]
# # LUNG CANCER PREDICTION

# %% [markdown]
# # EDA

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/datasets/survey lung cancer.csv')
df.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
df["FATIGUE "].unique()
# Out:
# array([2, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %%
df.shape
# Out:
# (309, 16)

# %% [markdown]
# Number of null values

# %%
df.isnull().sum()
# Out:
# GENDER                   0
# AGE                      0
# SMOKING                  0
# YELLOW_FINGERS           0
# ANXIETY                  0
# PEER_PRESSURE            0
# CHRONIC DISEASE          0
# FATIGUE                  0
# ALLERGY                  0
# WHEEZING                 0
# ALCOHOL CONSUMING        0
# COUGHING                 0
# SHORTNESS OF BREATH      0
# SWALLOWING DIFFICULTY    0
# CHEST PAIN               0
# LUNG_CANCER              0
# dtype: int64

# %% [markdown]
# **The dataset has no null values.**

# %% [markdown]
# Duplicate values

# %%
print(df.duplicated().sum())
# Out:
# 33

# %% [markdown]
# The dataset has 33 duplicate values.

# %% [markdown]
# Decided to drop the duplicates for accuracy

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Statistics on the Age Column.

# %%
df['AGE'].describe()
# Out:
# count    276.000000
# mean      62.909420
# std        8.379355
# min       21.000000
# 25%       57.750000
# 50%       62.500000
# 75%       69.000000
# max       87.000000
# Name: AGE, dtype: float64

# %% [markdown]
# **Cleaning**

# %%
df.loc[df['LUNG_CANCER'] == 'NO', 'LUNG_CANCER'] = 0
df.loc[df['LUNG_CANCER'] == 'YES', 'LUNG_CANCER'] = 1

# %%
df.head(5)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2           1
# 1                    2                      2           2           1
# 2                    2                      1           2           0
# 3                    1                      2           2           0
# 4                    2                      1           1           0

# %%
df["LUNG_CANCER"].unique()
# Out:
# array([1, 0], dtype=object)

# %%
df["FATIGUE "].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    1
# 4    1
# Name: FATIGUE , dtype: int64

# %%
df['LUNG_CANCER'].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: LUNG_CANCER, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 276 entries, 0 to 283
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    object
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
#  15  LUNG_CANCER            276 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 44.8+ KB

# %% [markdown]
# **INSIGHTS**

# %% [markdown]
# Chance of Cancer based on gender

# %%
# Cancer rate per gender
df.groupby(["LUNG_CANCER", "GENDER"])["GENDER"].count()
# Out:
# LUNG_CANCER  GENDER
# 0            F          21
#              M          17
# 1            F         113
#              M         125
# Name: GENDER, dtype: int64

# %% [markdown]
# Majority of the Females and Males have Lung cancer.

# %%
survived_rate_gender = df.groupby(["GENDER"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
survived_rate_gender['survival_rate'] = round(survived_rate_gender['Cancer']/survived_rate_gender['total_pat']*100, 2)
display(survived_rate_gender)
# Out:
#         total_pat Cancer survival_rate
# GENDER
# F             134    113     84.328358
# M             142    125     88.028169

# %%
df['LUNG_CANCER'].unique()
# Out:
# array([1, 0], dtype=object)

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %% [markdown]
# This shows that Males have a slightly high chance of getting  Lung cancer than the females.

# %% [markdown]
# **Chance of Lung Cancer according to age**

# %%
df["AGE"].unique()
# Out:
# array([69, 74, 59, 63, 75, 52, 51, 68, 53, 61, 72, 60, 58, 48, 57, 44, 64,
#        21, 65, 55, 62, 56, 67, 77, 70, 54, 49, 73, 47, 71, 66, 76, 78, 81,
#        79, 38, 39, 87, 46])

# %% [markdown]
# There are no kids or teenagers with Lung Cancer

# %%
df["Age_bracket"] = ""

df.loc[(df["AGE"] > 19) & (df["AGE"] <=30 ), "Age_bracket"] = "Young_Adults"
df.loc[df["AGE"] >=30 & (df["AGE"] <=60 ), "Age_bracket"] = "Adults"
df.loc[df["AGE"] > 60, "Age_bracket"] = "Seniors"


df.head(20)
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       M   69        1               2        2              1
# 1       M   74        2               1        1              1
# 2       F   59        1               1        1              2
# 3       M   63        2               2        2              1
# 4       F   63        1               2        1              1
# 5       F   75        1               2        1              1
# 6       M   52        2               1        1              1
# 7       F   51        2               2        2              2
# 8       F   68        2               1        2              1
# 9       M   53        2               2        2              2
# 10      F   61        2               2        2              2
# 11      M   72        1               1        1              1
# 12      F   60        2               1        1              1
# 13      M   58        2               1        1              1
# 14      M   69        2               1        1              1
# 15      F   48        1               2        2              2
# 16      M   75        2               1        1              1
# 17      M   57        2               2        2              2
# 18      F   68        2               2        2              2
# 19      F   61        1               1        1              1
#
#     CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                 1         2         1         2                  2
# 1                 2         2         2         1                  1
# 2                 1         2         1         2                  1
# 3                 1         1         1         1                  2
# 4                 1         1         1         2                  1
# 5                 2         2         2         2                  1
# 6                 1         2         1         2                  2
# 7                 1         2         2         1                  1
# 8                 1         2         1         1                  1
# 9                 2         1         2         1                  2
# 10                2         2         1         2                  1
# 11                2         2         2         2                  2
# 12                1         2         1         1                  1
# 13                1         2         2         2                  2
# 14                1         1         2         2                  2
# 15                2         2         2         2                  1
# 16                2         1         2         2                  2
# 17                2         1         1         1                  2
# 18                2         2         1         1                  1
# 19                2         2         1         1                  1
#
#     COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0          2                    2                      2           2
# 1          1                    2                      2           2
# 2          2                    2                      1           2
# 3          1                    1                      2           2
# 4          2                    2                      1           1
# 5          2                    2                      1           1
# 6          2                    2                      1           2
# 7          1                    2                      2           1
# 8          1                    1                      1           1
# 9          1                    1                      2           2
# 10         2                    2                      2           1
# 11         2                    2                      1           2
# 12         1                    2                      1           1
# 13         2                    2                      1           2
# 14         2                    1                      1           2
# 15         2                    2                      2           1
# 16         2                    2                      1           2
# 17         1                    1                      2           2
# 18         2                    2                      1           1
# 19         1                    2                      1           1
#
#    LUNG_CANCER Age_bracket
# 0            1     Seniors
# 1            1     Seniors
# 2            0      Adults
# 3            0     Seniors
# 4            0     Seniors
# 5            1     Seniors
# 6            1      Adults
# 7            1      Adults
# 8            0     Seniors
# 9            1      Adults
# 10           1     Seniors
# 11           1     Seniors
# 12           0      Adults
# 13           1      Adults
# 14           0     Seniors
# 15           1      Adults
# 16           1     Seniors
# 17           1      Adults
# 18           1     Seniors
# 19           0     Seniors

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 276 entries, 0 to 283
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    object
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
#  15  LUNG_CANCER            276 non-null    object
#  16  Age_bracket            276 non-null    object
# dtypes: int64(14), object(3)
# memory usage: 46.9+ KB

# %%
cancer_rate_age = df.groupby(["Age_bracket"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_rate_age['cancer_chance'] = round(cancer_rate_age['Cancer']/cancer_rate_age['total_pat']*100, 2)
display(cancer_rate_age)
# Out:
#              total_pat Cancer cancer_chance
# Age_bracket
# Adults             108     89     82.407407
# Seniors            168    149     88.690476

# %% [markdown]
# This shows that seniors have a high percentage of getting cancer other than the alduts

# %% [markdown]
# **Smoking**

# %%
df.groupby("GENDER")["SMOKING"].value_counts()
# Out:
# GENDER  SMOKING
# F       2          70
#         1          64
# M       2          80
#         1          62
# Name: count, dtype: int64

# %% [markdown]
# There are more males than females who are smoking

# %%
df.groupby("Age_bracket")["SMOKING"].value_counts()
# Out:
# Age_bracket  SMOKING
# Adults       2          60
#              1          48
# Seniors      2          90
#              1          78
# Name: count, dtype: int64

# %% [markdown]
# There are more seniors who are smoking

# %%
cancer_by_smoking = df.groupby(["SMOKING"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_smoking['survival_rate'] = round(cancer_by_smoking['Cancer']/cancer_by_smoking['total_pat']*100, 2)
display(cancer_by_smoking)
# Out:
#          total_pat Cancer survival_rate
# SMOKING
# 1              126    107     84.920635
# 2              150    131     87.333333

# %% [markdown]
# Where 1 represents no and 2 Yes it shows that chances if they smoke

# %% [markdown]
# **chance of cancer with yellow fingers**

# %%
df.groupby("GENDER")["YELLOW_FINGERS"].value_counts()
# Out:
# GENDER  YELLOW_FINGERS
# F       2                 91
#         1                 43
# M       1                 74
#         2                 68
# Name: count, dtype: int64

# %% [markdown]
# There are more females than males who have yellow fingers

# %%
df.groupby("Age_bracket")["YELLOW_FINGERS"].value_counts()
# Out:
# Age_bracket  YELLOW_FINGERS
# Adults       2                  59
#              1                  49
# Seniors      2                 100
#              1                  68
# Name: count, dtype: int64

# %% [markdown]
# There are many seniors with yellow fingers

# %%
cancer_by_yellowF = df.groupby(["YELLOW_FINGERS"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_yellowF['cancer_chance'] = round(cancer_by_yellowF['Cancer']/cancer_by_yellowF['total_pat']*100, 2)
display(cancer_by_yellowF)
# Out:
#                 total_pat Cancer cancer_chance
# YELLOW_FINGERS
# 1                     117     92     78.632479
# 2                     159    146     91.823899

# %% [markdown]
# High chance of cancer if one has yellow fingers

# %% [markdown]
# **ANXIETY**

# %%
df.groupby("GENDER")["ANXIETY"].value_counts()
# Out:
# GENDER  ANXIETY
# F       2          77
#         1          57
# M       1          82
#         2          60
# Name: count, dtype: int64

# %% [markdown]
# More males experience anxiety than females

# %%
df.groupby("Age_bracket")["ANXIETY"].value_counts()
# Out:
# Age_bracket  ANXIETY
# Adults       1          59
#              2          49
# Seniors      2          88
#              1          80
# Name: count, dtype: int64

# %% [markdown]
# More seniors experience anxiety than the adults

# %%
cancer_by_anxiety = df.groupby(["ANXIETY"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_anxiety['cancer_chance'] = round(cancer_by_anxiety['Cancer']/cancer_by_anxiety['total_pat']*100, 2)
display(cancer_by_anxiety)
# Out:
#          total_pat Cancer cancer_chance
# ANXIETY
# 1              139    113     81.294964
# 2              137    125     91.240876

# %% [markdown]
# High chance of cancer if one has anxiety

# %% [markdown]
# **PEER_PRESSURE**

# %%
df.groupby("GENDER")["PEER_PRESSURE"].value_counts()
# Out:
# GENDER  PEER_PRESSURE
# F       2                86
#         1                48
# M       1                88
#         2                54
# Name: count, dtype: int64

# %% [markdown]
# More females than males experience peer pressure

# %%
df.groupby("Age_bracket")["PEER_PRESSURE"].value_counts()
# Out:
# Age_bracket  PEER_PRESSURE
# Adults       1                55
#              2                53
# Seniors      2                87
#              1                81
# Name: count, dtype: int64

# %% [markdown]
# Seniors experience Peer pressure more than the adults

# %%
cancer_by_peerpressure = df.groupby(["PEER_PRESSURE"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_peerpressure['cancer_chance'] = round(cancer_by_peerpressure['Cancer']/cancer_by_peerpressure['total_pat']*100, 2)
display(cancer_by_peerpressure)
# Out:
#                total_pat Cancer cancer_chance
# PEER_PRESSURE
# 1                    136    108     79.411765
# 2                    140    130     92.857143

# %% [markdown]
# High chance of cancer if one has peer pressure

# %% [markdown]
# **Chronic disease**

# %%
df.groupby("GENDER")["CHRONIC DISEASE"].value_counts()
# Out:
# GENDER  CHRONIC DISEASE
# F       2                  83
#         1                  51
# M       1                  81
#         2                  61
# Name: count, dtype: int64

# %% [markdown]
# Females experience chronic diseases more than the males

# %%
df.groupby("Age_bracket")["CHRONIC DISEASE"].value_counts()
# Out:
# Age_bracket  CHRONIC DISEASE
# Adults       2                  59
#              1                  49
# Seniors      2                  85
#              1                  83
# Name: count, dtype: int64

# %% [markdown]
# More seniors have chronic disease than adults

# %%
cancer_by_CD= df.groupby(["CHRONIC DISEASE"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_CD['cancer_chance'] = round(cancer_by_CD['Cancer']/cancer_by_CD['total_pat']*100, 2)
display(cancer_by_CD)
# Out:
#                  total_pat Cancer cancer_chance
# CHRONIC DISEASE
# 1                      132    107     81.060606
# 2                      144    131     90.972222

# %% [markdown]
# High chance of cancer if one has a chronic disease

# %% [markdown]
# **FATIGUE**

# %%
df.groupby("GENDER")["FATIGUE "].value_counts()
# Out:
# GENDER  FATIGUE
# F       2           94
#         1           40
# M       2           89
#         1           53
# Name: count, dtype: int64

# %% [markdown]
# Females experience fatigue more than males

# %%
df.groupby("Age_bracket")["FATIGUE "].value_counts()
# Out:
# Age_bracket  FATIGUE
# Adults       2            70
#              1            38
# Seniors      2           113
#              1            55
# Name: count, dtype: int64

# %% [markdown]
# Seniors experience Fatigue more than adults

# %%
cancer_by_fatigue= df.groupby(["FATIGUE "]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_fatigue['cancer_chance'] = round(cancer_by_fatigue['Cancer']/cancer_by_fatigue['total_pat']*100, 2)
display(cancer_by_fatigue)
# Out:
#           total_pat Cancer cancer_chance
# FATIGUE
# 1                93     73     78.494624
# 2               183    165     90.163934

# %% [markdown]
# High percentage of Cancer if one experiences fatigue

# %% [markdown]
# **Allergy**

# %%
df.groupby("GENDER")["ALLERGY "].value_counts()
# Out:
# GENDER  ALLERGY
# F       1           71
#         2           63
# M       2           88
#         1           54
# Name: count, dtype: int64

# %% [markdown]
# Males have the most experience with allergy than the females

# %%
df.groupby("Age_bracket")["ALLERGY "].value_counts()
# Out:
# Age_bracket  ALLERGY
# Adults       2           55
#              1           53
# Seniors      2           96
#              1           72
# Name: count, dtype: int64

# %% [markdown]
# Seniors have more expreince on allergy than adults

# %%
cancer_by_allergy= df.groupby(["ALLERGY "]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_allergy['cancer_chance'] = round(cancer_by_allergy['Cancer']/cancer_by_allergy['total_pat']*100, 2)
display(cancer_by_allergy)
# Out:
#           total_pat Cancer cancer_chance
# ALLERGY
# 1               125     92          73.6
# 2               151    146     96.688742

# %% [markdown]
# Very high chance of Cancer if one has allergy

# %% [markdown]
# **Wheezing**

# %%
df.groupby("GENDER")["WHEEZING"].value_counts()
# Out:
# GENDER  WHEEZING
# F       1           69
#         2           65
# M       2           86
#         1           56
# Name: count, dtype: int64

# %% [markdown]
# Males have more experience with wheezing

# %%
df.groupby("Age_bracket")["WHEEZING"].value_counts()
# Out:
# Age_bracket  WHEEZING
# Adults       2           58
#              1           50
# Seniors      2           93
#              1           75
# Name: count, dtype: int64

# %% [markdown]
# Seniors wheeze a lot than the adults

# %%
cancer_by_wheezing= df.groupby(["WHEEZING"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_wheezing['cancer_chance'] = round(cancer_by_wheezing['Cancer']/cancer_by_wheezing['total_pat']*100, 2)
display(cancer_by_wheezing)
# Out:
#           total_pat Cancer cancer_chance
# WHEEZING
# 1               125     96          76.8
# 2               151    142     94.039735

# %% [markdown]
# Very high percentage of Cancer if one experiences wheezing

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER', 'Age_bracket'],
#       dtype='object')

# %% [markdown]
# **Alcohol**

# %%
df.groupby("GENDER")["ALCOHOL CONSUMING"].value_counts()
# Out:
# GENDER  ALCOHOL CONSUMING
# F       1                     90
#         2                     44
# M       2                    108
#         1                     34
# Name: count, dtype: int64

# %% [markdown]
# Males consume alcohol more that the females

# %%
df.groupby("Age_bracket")["ALCOHOL CONSUMING"].value_counts()
# Out:
# Age_bracket  ALCOHOL CONSUMING
# Adults       2                    57
#              1                    51
# Seniors      2                    95
#              1                    73
# Name: count, dtype: int64

# %% [markdown]
# Seniors consume more alcohol

# %%
cancer_by_alcohol= df.groupby(["ALCOHOL CONSUMING"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_alcohol['cancer_chance'] = round(cancer_by_alcohol['Cancer']/cancer_by_alcohol['total_pat']*100, 2)
display(cancer_by_alcohol)
# Out:
#                    total_pat Cancer cancer_chance
# ALCOHOL CONSUMING
# 1                        124     93          75.0
# 2                        152    145     95.394737

# %% [markdown]
# Very high chance of cancer if one consumes alcohol

# %% [markdown]
# **Coughing**

# %%
df.groupby("GENDER")["COUGHING"].value_counts()
# Out:
# GENDER  COUGHING
# F       2           69
#         1           65
# M       2           90
#         1           52
# Name: count, dtype: int64

# %% [markdown]
# Males are coughing more than the females

# %%
df.groupby("Age_bracket")["COUGHING"].value_counts()
# Out:
# Age_bracket  COUGHING
# Adults       1            55
#              2            53
# Seniors      2           106
#              1            62
# Name: count, dtype: int64

# %% [markdown]
# Seniors are coughing more

# %%
cancer_by_coughing= df.groupby(["COUGHING"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_coughing['cancer_chance'] = round(cancer_by_coughing['Cancer']/cancer_by_coughing['total_pat']*100, 2)
display(cancer_by_coughing)
# Out:
#           total_pat Cancer cancer_chance
# COUGHING
# 1               117     89     76.068376
# 2               159    149     93.710692

# %% [markdown]
# Very high chance of cancer if one coughs

# %% [markdown]
# **Shortness of breath**

# %%
df.groupby("GENDER")["SHORTNESS OF BREATH"].value_counts()
# Out:
# GENDER  SHORTNESS OF BREATH
# F       2                      88
#         1                      46
# M       2                      86
#         1                      56
# Name: count, dtype: int64

# %% [markdown]
# Females are experiencing shortness of breath more though the gap is not as big

# %%
df.groupby("Age_bracket")["SHORTNESS OF BREATH"].value_counts()
# Out:
# Age_bracket  SHORTNESS OF BREATH
# Adults       2                       67
#              1                       41
# Seniors      2                      107
#              1                       61
# Name: count, dtype: int64

# %% [markdown]
# Seniors are experiencing shortness of breathe more than the adults

# %%
cancer_by_shortness_of_breath= df.groupby(["SHORTNESS OF BREATH"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_shortness_of_breath['cancer_chance'] = round(cancer_by_shortness_of_breath['Cancer']/cancer_by_shortness_of_breath['total_pat']*100, 2)
display(cancer_by_shortness_of_breath)
# Out:
#                      total_pat Cancer cancer_chance
# SHORTNESS OF BREATH
# 1                          102     85     83.333333
# 2                          174    153     87.931034

# %% [markdown]
# High chance of cancer if one expiriences shortness of breath

# %% [markdown]
# **Swallowing Difficulty**

# %%
df.groupby("GENDER")["SWALLOWING DIFFICULTY"].value_counts()
# Out:
# GENDER  SWALLOWING DIFFICULTY
# F       1                        68
#         2                        66
# M       1                        79
#         2                        63
# Name: count, dtype: int64

# %% [markdown]
# Majority of both genders are not experiencing swallowing difficulty. And those one that are majority are the females

# %%
df.groupby("Age_bracket")["SWALLOWING DIFFICULTY"].value_counts()
# Out:
# Age_bracket  SWALLOWING DIFFICULTY
# Adults       1                        58
#              2                        50
# Seniors      1                        89
#              2                        79
# Name: count, dtype: int64

# %% [markdown]
# Majority of both Age_brackets are not experiencing swallowing difficulty. And those one that are majority are the seniors

# %%
cancer_by_swallowing_diff= df.groupby(["SWALLOWING DIFFICULTY"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_swallowing_diff['cancer_chance'] = round(cancer_by_swallowing_diff['Cancer']/cancer_by_swallowing_diff['total_pat']*100, 2)
display(cancer_by_swallowing_diff)
# Out:
#                        total_pat Cancer cancer_chance
# SWALLOWING DIFFICULTY
# 1                            147    114      77.55102
# 2                            129    124     96.124031

# %% [markdown]
# High chance of cancer if one experiences swallowing difficulty

# %% [markdown]
# **Chest pain**

# %%
df.groupby("GENDER")["CHEST PAIN"].value_counts()
# Out:
# GENDER  CHEST PAIN
# F       1              84
#         2              50
# M       2             104
#         1              38
# Name: count, dtype: int64

# %% [markdown]
# Majority of the males are having chest pains

# %%
df.groupby("Age_bracket")["CHEST PAIN"].value_counts()
# Out:
# Age_bracket  CHEST PAIN
# Adults       2             63
#              1             45
# Seniors      2             91
#              1             77
# Name: count, dtype: int64

# %% [markdown]
# Seniors are the majority experiencing chest pains

# %%
cancer_by_chest_pain= df.groupby(["CHEST PAIN"]).agg(
    total_pat = ('GENDER', 'size'),
    Cancer = ('LUNG_CANCER', 'sum')
)
cancer_by_chest_pain['cancer_chance'] = round(cancer_by_chest_pain['Cancer']/cancer_by_chest_pain['total_pat']*100, 2)
display(cancer_by_chest_pain)
# Out:
#             total_pat Cancer cancer_chance
# CHEST PAIN
# 1                 122     96     78.688525
# 2                 154    142     92.207792

# %% [markdown]
# High chance of cancer if one has Chest pains

# %% [markdown]
# CORRELATION GRAPGH TO SEE WHICH COLUMNS STRONGLY CORRELATE TO EACH OTHER

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x='LUNG_CANCER', data=df)
plt.title("Target Class Distribution")
plt.show()

print(df['LUNG_CANCER'].value_counts(normalize=True))
# Out:
# LUNG_CANCER
# 1    0.862319
# 0    0.137681
# Name: proportion, dtype: float64

# %% [markdown]
# In the above insights all symptoms showcase that if you have it, you have a high percentage of having lung cancer. This therefore showcases how unbalanced the dataset is. Hence the smote technique will be used in model training

# %% [markdown]
# # MODEL TRAINING

# %% [markdown]
# I decided to use Random Forest since it deals with imbalances.

# %% [markdown]
# Training the model before SMOTE

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.metrics import accuracy_score

from imblearn.over_sampling import SMOTE

# %% [markdown]
# Splitting the data

# %% [markdown]
# Since some of my columns are categorical i want to changethe data types

# %%
df.loc[df['GENDER'] == 'M', 'GENDER'] = 0
df.loc[df['GENDER'] == 'F', 'GENDER'] = 1

# %%
df = pd.get_dummies(df, columns=['Age_bracket'], drop_first=False)

# %%
df["Age_bracket_Adults"] = df["Age_bracket_Adults"].astype(int)
df["Age_bracket_Seniors"] = df["Age_bracket_Seniors"].astype(int)

# %%
df["GENDER"] = df["GENDER"].astype(int)
df["LUNG_CANCER"] = df["LUNG_CANCER"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 276 entries, 0 to 283
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 276 non-null    int64
#  1   AGE                    276 non-null    int64
#  2   SMOKING                276 non-null    int64
#  3   YELLOW_FINGERS         276 non-null    int64
#  4   ANXIETY                276 non-null    int64
#  5   PEER_PRESSURE          276 non-null    int64
#  6   CHRONIC DISEASE        276 non-null    int64
#  7   FATIGUE                276 non-null    int64
#  8   ALLERGY                276 non-null    int64
#  9   WHEEZING               276 non-null    int64
#  10  ALCOHOL CONSUMING      276 non-null    int64
#  11  COUGHING               276 non-null    int64
#  12  SHORTNESS OF BREATH    276 non-null    int64
#  13  SWALLOWING DIFFICULTY  276 non-null    int64
#  14  CHEST PAIN             276 non-null    int64
#  15  LUNG_CANCER            276 non-null    int64
#  16  Age_bracket_Adults     276 non-null    int64
#  17  Age_bracket_Seniors    276 non-null    int64
# dtypes: int64(18)
# memory usage: 49.1 KB

# %%
df.head(5)
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       0   69        1               2        2              1
# 1       0   74        2               1        1              1
# 2       1   59        1               1        1              2
# 3       0   63        2               2        2              1
# 4       1   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER  \
# 0                    2                      2           2            1
# 1                    2                      2           2            1
# 2                    2                      1           2            0
# 3                    1                      2           2            0
# 4                    2                      1           1            0
#
#    Age_bracket_Adults  Age_bracket_Seniors
# 0                   0                    1
# 1                   0                    1
# 2                   1                    0
# 3                   0                    1
# 4                   0                    1

# %% [markdown]
# Evaluating the model before SMOTE

# %%
X = df.drop(columns=['LUNG_CANCER','Age_bracket_Adults', 'Age_bracket_Seniors'], axis=1)
y = df['LUNG_CANCER']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Make predictions
y_pred = rf.predict(X_test)

# Accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Accuracy: 0.88
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.38      0.56        13
#            1       0.88      1.00      0.93        56
#
#     accuracy                           0.88        69
#    macro avg       0.94      0.69      0.74        69
# weighted avg       0.90      0.88      0.86        69
#
# Confusion Matrix:
# [[ 5  8]
#  [ 0 56]]

# %% [markdown]
# Before smote, the acurracy is 88%

# %%
import pandas as pd

# Get feature importances
importances = rf.feature_importances_
feature_names = X.columns

# Put into a DataFrame
feat_imp = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x='Importance', y='Feature', data=feat_imp)
plt.title('Feature Importance from Random Forest')
plt.tight_layout()
plt.show()

# %% [markdown]
# Evaluating the model after SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Re-split your data just in case
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
print("Before SMOTE:")
print(y_train.value_counts())

print("\nAfter SMOTE:")
print(pd.Series(y_train_smote).value_counts())
# Out:
# Before SMOTE:
# LUNG_CANCER
# 1    182
# 0     25
# Name: count, dtype: int64
#
# After SMOTE:
# LUNG_CANCER
# 1    182
# 0    182
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

rf_smote = RandomForestClassifier(n_estimators=100, random_state=42)
rf_smote.fit(X_train_smote, y_train_smote)

# Predict on test set
y_pred_smote = rf_smote.predict(X_test)

accuracy_smote = accuracy_score(y_test, y_pred_smote)
print(f"Accuracy after SMOTE: {accuracy_smote:.2f}")
# Out:
# Accuracy after SMOTE: 0.90

# %% [markdown]
# After Smote, the accuracy went up to 91%

# %%
# Get feature importances
importances = rf_smote.feature_importances_

# Match them to column names
feature_names = X.columns  # or X_train.columns if they differ
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=importance_df.head(10), x='Importance', y='Feature')
plt.title("Top 10 Feature Importances (After SMOTE)")
plt.xlabel("Importance Score")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# The top ten features that influence the model's prediction.

# %%
import joblib

# Save model
joblib.dump(rf_smote, 'model.pkl')

# Save columns used for training
joblib.dump(X.columns.tolist(), 'columns.pkl')
# Out:
# ['columns.pkl']

# %%
from google.colab import files

# Download model and columns files
files.download('model.pkl')
files.download('columns.pkl')
